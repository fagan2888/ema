# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import os
from functools import reduce
from itertools import chain
import pandas as pd
import json
from tqdm import tqdm
from pprint import pprint
from collections import defaultdict
from ema.utils import get_names_synonyms_doid, get_doid_names, clean_text, contains_word
from wikidataintegrator import wdi_helpers, wdi_core

DATA_DIR = "../data"
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# run match_drugs first

# %%
df = pd.read_csv("eu_orphan.csv", index_col=0)
df.head()
# Out:
#                                              Product EU Designation  \
# 0  11-(2-pyrrolidin-1-yl-ethoxy)-14,19-dioxa-5,7,...    EU/3/10/767
# 1  11-(2-pyrrolidin-1-yl-ethoxy)-14,19-dioxa-5,7,...    EU/3/10/768
# 2  11-(2-pyrrolidin-1-yl-ethoxy)-14,19-dioxa-5,7,...    EU/3/10/769
# 3  11-(4-Dimethylamino-3-hydroxy-6-methyl-tetrahy...   EU/3/14/1239
# 4  1-(2,2-difluoro-1,3-benzodioxol-5-yl)-N-{1-[(2...   EU/3/14/1281
#
#                         Designated Orphan Indication  \
# 0  Treatment of post-essential thrombocythaemia m...
# 1                 Treatment of primary myelofibrosis
# 2  Treatment of post-polycythaemia vera myelofibr...
# 3                       Treatment of cystic fibrosis
# 4                       Treatment of cystic fibrosis
#
#                                    Sponsor Designation date  \
# 0                    CTI Life Sciences Ltd       25/08/2010
# 1                    CTI Life Sciences Ltd       25/08/2010
# 2                    CTI Life Sciences Ltd       25/08/2010
# 3                              Synovo GmbH       19/02/2014
# 4  Vertex Pharmaceuticals (Europe) Limited       04/07/2014
#
#   TradenameEU Centralised NrImplemented on drug_qid
# 0                                      NaN      NaN
# 1                                      NaN      NaN
# 2                                      NaN      NaN
# 3                                      NaN      NaN
# 4                                      NaN      NaN

# %%
first_word = df['Designated Orphan Indication'].str.split(" ").apply(lambda x:x[0].lower())
first_word.value_counts().head()
# Out:
# treatment       1341
# prevention        73
# diagnosis         12
# conditioning       2
# adjunctive         2
# Name: Designated Orphan Indication, dtype: int64

# %%
# these don't fit the pattern!! Skip them for now
baddies = ~first_word.isin({'treatment', 'prevention', 'diagnosis'})
df[baddies]
# Out:
#                                                 Product EU Designation  \
# 134                 5-aminolevulinic acid hydrochloride    EU/3/02/121
# 185   Adeno-associated viral vector serotype 2 conta...   EU/3/14/1278
# 408                                 Carboxypeptidase G2    EU/3/02/128
# 650   Herpes simplex 1 virus-thymidine kinase and tr...    EU/3/03/168
# 1306                                         Somatropin    EU/3/00/001
# 1353                                           Thiotepa    EU/3/06/424
# 1373                                         Treosulfan    EU/3/04/186
#
#                            Designated Orphan Indication  \
# 134   Intra-operative photodynamic diagnosis of resi...
# 185                         'Treatment of choroideremia
# 408   Adjunctive treatment in patients at risk of me...
# 650   Adjunctive treatment in hematopoietic cell tra...
# 1306                                       AIDS wasting
# 1353  Conditioning treatment prior to haematopoietic...
# 1373  Conditioning treatment prior to haematopoietic...
#
#                                                 Sponsor Designation date  \
# 134   medac Gesellschaft für klinische Spezialpräpar...       13/11/2002
# 185                           Alan Boyd Consultants Ltd       04/06/2014
# 408                     BTG Management Services Limited       03/02/2003
# 650                                       MolMed S.p.A.       20/10/2003
# 1306                        Merck Serono Europe Limited       08/08/2000
# 1353                                     ADIENNE S.r.l.       29/01/2007
# 1373  medac Gesellschaft für klinische Spezialpräpar...       23/02/2004
#
#      TradenameEU Centralised NrImplemented on   drug_qid
# 134              GliolanEU/1/07/41312/09/2007        NaN
# 185                                       NaN        NaN
# 408                                       NaN   Q5572303
# 650            ZalmoxisEU/1/16/112123/08/2016        NaN
# 1306                                      NaN  Q20801765
# 1353            TepadinaEU/1/10/62217/03/2010    Q416507
# 1373                                      NaN   Q7838652

# %%
df = df[~baddies]

# %%
df.loc[:, 'indication'] = df['Designated Orphan Indication'].str.split(" ").apply(lambda x: " ".join(x[2:]).lower())
df.head()
# Out:
#                                              Product EU Designation  \
# 0  11-(2-pyrrolidin-1-yl-ethoxy)-14,19-dioxa-5,7,...    EU/3/10/767
# 1  11-(2-pyrrolidin-1-yl-ethoxy)-14,19-dioxa-5,7,...    EU/3/10/768
# 2  11-(2-pyrrolidin-1-yl-ethoxy)-14,19-dioxa-5,7,...    EU/3/10/769
# 3  11-(4-Dimethylamino-3-hydroxy-6-methyl-tetrahy...   EU/3/14/1239
# 4  1-(2,2-difluoro-1,3-benzodioxol-5-yl)-N-{1-[(2...   EU/3/14/1281
#
#                         Designated Orphan Indication  \
# 0  Treatment of post-essential thrombocythaemia m...
# 1                 Treatment of primary myelofibrosis
# 2  Treatment of post-polycythaemia vera myelofibr...
# 3                       Treatment of cystic fibrosis
# 4                       Treatment of cystic fibrosis
#
#                                    Sponsor Designation date  \
# 0                    CTI Life Sciences Ltd       25/08/2010
# 1                    CTI Life Sciences Ltd       25/08/2010
# 2                    CTI Life Sciences Ltd       25/08/2010
# 3                              Synovo GmbH       19/02/2014
# 4  Vertex Pharmaceuticals (Europe) Limited       04/07/2014
#
#   TradenameEU Centralised NrImplemented on drug_qid  \
# 0                                      NaN      NaN
# 1                                      NaN      NaN
# 2                                      NaN      NaN
# 3                                      NaN      NaN
# 4                                      NaN      NaN
#
#                                       indication
# 0  post-essential thrombocythaemia myelofibrosis
# 1                          primary myelofibrosis
# 2          post-polycythaemia vera myelofibrosis
# 3                                cystic fibrosis
# 4                                cystic fibrosis

# %%
# get rid of ' ’ -
rep = {'’': '', '\'': '', '-': '', 'ae': 'e', '`': '', '‘': '', 'ou': 'o', 'ze': 'se', '&#8217;': '', '&#945;': 'α'}
replace_multi = lambda s: reduce(lambda a, kv: a.replace(*kv), rep.items(), s)
df.indication = df.indication.str.lower().apply(replace_multi)
diseases = set(list(df['indication'].dropna().str.strip())) - {""}
len(diseases)
# Out:
# 525

# %% [markdown]
# ## orphanet
# http://data.bioontology.org/ontologies/ORDO/download?apikey=8b5b7825-538d-40e0-9e9e-5ab9274a9aeb&download_format=csv

# %%
ordo = pd.read_csv("ORDO.csv.gz")
ordo.dropna(subset=['Preferred Label'], inplace=True)
name_ordo = dict(zip(ordo['Preferred Label'].str.lower(), ordo['Class ID']))
name_ordo = {replace_multi(k): v for k,v in name_ordo.items()}
len(name_ordo)
# Out:
# 13318

# %%
for _, row in ordo[ordo.Synonyms.notnull()].iterrows():
    for syn in row.Synonyms.split("|"):
        name_ordo[replace_multi(syn.lower())] = row['Class ID']
del name_ordo['disease']
len(name_ordo)
# Out:
# 33194

# %%
ordo_matches = {x:name_ordo[x] for x in diseases if x in name_ordo}
len(ordo_matches)
# Out:
# 213

# %% [markdown]
# ### DO and HPO

# %%
# match to DO or HPO
def onto_synonyms(json_path):
    doid = json.loads(open(json_path).read())
    graph = doid['graphs'][0]
    nodes = graph['nodes']
    name_doid = dict()
    for node in nodes:
        if 'meta' in node and 'deprecated' in node['meta'] and node['meta']['deprecated']:
            continue
        if 'lbl' not in node:
            continue
        name_doid[replace_multi(node['lbl'].lower())] = node['id']
        if 'meta' in node and 'synonyms' in node['meta']:
            for syn in node['meta']['synonyms']:
                name_doid[replace_multi(syn['val'].lower())] = node['id']
    return name_doid
name_doid = onto_synonyms("../data/doid.json")
name_hpo = onto_synonyms("../data/hp.json")
print(len(name_doid))
print(len(name_hpo))
# Out:
# 21023
# 26569

# %%
doid_matches = {x:name_doid[x] for x in diseases if x in name_doid}
len(doid_matches)
# Out:
# 193

# %%
hpo_matches = {x:name_hpo[x] for x in diseases if x in name_hpo}
len(hpo_matches)
# Out:
# 69

# %% [markdown]
# ### mesh

# %%
# create mesh title synonyms dict
# json is created from https://github.com/stuppie/mesh-parser
mesh = json.load(open("/home/gstupp/projects/mesh/mesh.json"))
name_mesh = dict()
for record in mesh.values():
    if record['record_type'] == 'C':
        continue
    name_mesh[replace_multi(record['term']).lower()] = record['_id']
    for syn in record.get('synonyms', []):
        name_mesh[replace_multi(syn).lower()] = record['_id']
mesh_name = {v:k for k,v in name_mesh.items()}

# %%
mesh_matches = {x:name_mesh[x] for x in diseases if x in name_mesh}
len(mesh_matches)
# Out:
# 228

# %%
diseases_not_matched = {x for x in diseases if x not in doid_matches and x not in ordo_matches and x not in mesh_matches and x not in hpo_matches}
len(diseases_not_matched)
# Out:
# 229

# %%
diseases_not_matched
# Out:
# {'5fluororacil overdose',
#  '5q spinal muscular atrophy',
#  'achromatopsia caused by mutations in the cnga3 gene',
#  'achromatopsia caused by mutations in the cngb3',
#  'achromatopsia caused by mutations in the cngb3 gene',
#  'active ulcerative colitis',
#  'acute myleoid leukemia',
#  'acute peripheral arterial occlusion',
#  'acute sensorineural hearing loss (acute acostic trauma, sudden deafness and surgery induced acostic trauma)',
#  'adenosine deaminasedeficientsevere combined immunodeficiency',
#  'adenovirus infection following hematopoietic stem cell transplantation',
#  'adenovirus infection in allogeneic hematopoietic stemcell transplant recipients',
#  'adenovirus infection in immunocompromised patients',
#  'adrenocorticotropindependent cushings syndrome',
#  'aicardigoti&egrave;res syndrome',
#  'alstr&oml;m syndrome',
#  'amyloid lightchain amyloidosis',
#  'arteriovenos access dysfunction in hemodialysis patients',
#  'arteriovenos access dysfunction in patients undergoing surgical creation of an arteriovenos access for hemodialysis',
#  'arteriovenos access failure in hemodialysis patients',
#  'attr amyloidosis',
#  'atypical hemolytic uremic syndrome (ahus) associated with an inherited abnormality of the complement system',
#  'autoimmune uveitis',
#  'autosomal dominant polycystic kidney disease',
#  'bcell acute lymphoblastic leukemia',
#  'bcell chronic lymphocytic leukemia (bcll)',
#  'beh&ccedil;ets disease',
#  'behavioral variant frontotemporal dementia',
#  'beta thalassemia intermedia and major',
#  'betathalassemia intermedia and major',
#  'blymphoblastic leukemia/lymphoma',
#  'bronchopulmonary dysplasia in premature neonates of less than 30 weeks of gestational age',
#  'burkholderia cepacia lung infection in cystic fibrosis',
#  'cancers of the biliary tree',
#  'carbamoylphosphate synthase1 deficiency',
#  'carcinoid syndrome',
#  'chronic iron overload requiring chelation therapy',
#  'chronic lymphocytic leukemia / small lymphocytic lymphoma',
#  'chronic noninfectios uveitis',
#  'congenital alpha1 antitrypsin deficiency',
#  'congenital cytomegalovirus infection following primary cytomegalovirus infection',
#  'congenital muscular dystrophy with collagen vi deficiency (ullrich syndrome and bethlem myopathy).',
#  'congenital muscular dystrophy with merosin (laminin alpha 2) deficiency',
#  'corneal graft rejection',
#  'corneal lesions, with associated corneal (limbal) stem cell deficiency, due to ocular burns',
#  'creatine deficiency syndromes',
#  'cryopirinassociated periodic syndromes (familial cold urticaria syndrome (fcus), mucklewells syndrome (mws), and neonatal onset multisystem inflammatory disease (nomid), also known as chronic infantile neurological cutaneos articular syndrome (cinca)',
#  'cushings disease',
#  'cutaneos forms of lupus erythematosus',
#  'cytomegalovirus (cmv) disease in patients with impaired cell mediated immunity deemed at risk',
#  'cytomegalovirus disease',
#  'cytomegalovirus disease in patients with impaired cell mediated immunity',
#  'cytomegalovirus disease in patients with impaired cell mediated immunity deemed at risk',
#  'cytomegalovirus disease in patients with impaired cellmediated immunity deemed at risk',
#  'cytomegalovirus infection following hematopoietic stem cell transplantation',
#  'cytomegalovirus infection in patients with impaired cellmediated immunity',
#  'delayed graft function after renal transplantation',
#  'delayed graft function after solid organ transplantation',
#  'delayed graft function in organ transplant',
#  'diffuse large b cell lymphoma',
#  'dystrophic myotonia',
#  'emphysema secondary to congenital alpha 1antitrypsin deficiency',
#  'emphysema secondary to congenital alpha1 antitrypsin deficiency',
#  'eosinophilic oesophagitis',
#  'epcampositive squamos cell carcinoma of the head and neck',
#  'epithelial neoplasia of the vulva positive for human papilloma virus',
#  'epsteinbarr virus infection following hematopoietic stem cell transplantation',
#  'extranodal nk/tcell lymphoma, nasal type',
#  'familial benign chronic pemphigus (haileyhailey disease)',
#  'familial cerebral cavernos malformations',
#  'familial chylomicronemia syndrome (type i hyperlipoproteinemia)',
#  'fanconi anemia type a',
#  'fetal and neonatal alloimmune thrombocytopenia due to human platelet antigen1a incompatibility',
#  'follicular thyroid cancer',
#  'functional gastroenteropancreatic endocrine tumors',
#  'functional single ventricle congenital heart disease',
#  'gastric carcinoid',
#  'gastroenteropancreatic neuroendocrine tumors',
#  'globoid cell leukodystrophy (krabbe disease)',
#  'glucose transporter type1 deficiency syndrome',
#  'glycogen storage disease type ia',
#  'glycogen storage disease type ii (pompes disease)',
#  'graft loss in pancreatic islet transplantation',
#  'graft rejection during pancreatic islet transplantation',
#  'graft rejection following solid organ transplantation',
#  'graft rejection in pancreatic islet transplantation',
#  'gram negative bacteria lung infections in cystic fibrosis',
#  'guillainbarr&eacute; syndrome',
#  'hemophilia b (congenital factor ix deficiency)',
#  'hepatitis b reinfection following liver transplantation',
#  'hepatitis delta virus infection',
#  'hereditary factor x deficiency',
#  'herpes simplex virus stromal keratitis',
#  'high altitude pulmonary oedema',
#  'highgrade glioma',
#  'highgrade glioma with subsequent use of ganciclovir sodium',
#  'hutchinsongilford progeria',
#  'hypercortisolism (cushings syndrome) of endogenos origin',
#  'ileal poch anal anastomosis related fecal incontinence',
#  'inborn errors in primary bile acid synthesis',
#  'inborn errors of primary bile acid synthesis',
#  'inborn errors of primary bile acid synthesis responsive to treatment with cholic acid',
#  'intestinal graftversushost disease',
#  'invasive infections due to vancomycin resistant enterococci (vre) in colonised patients deemed at risk of infection',
#  'ischemia reperfusion injury associated with cardiac arrest',
#  'ischemia reperfusion injury associated with solid organ transplantation',
#  'ischemia/reperfusion injury associated with solid organ transplantation',
#  'lateonset sepsis in premature infants of less than or equal to 32 weeks of gestational age',
#  'lead toxicity',
#  'limbal stem cell deficiency',
#  'longchain 3hydroxyacylcoa dehydrogenase deficiency',
#  'low flow priapism',
#  'macular telangiectasia type 2',
#  'malabsorption due to exocrine pancreatic enzyme insufficiency',
#  'malignant gastro intestinal stromal tumors',
#  'mart1 positive malignant melanoma in hlaa2 positive patients',
#  'mercury toxicity',
#  'mitochondrial neurogastrointestinal encephalomyopathy (mngie) due to thymidine phosphorylase deficiency',
#  'mobilisation of progenitor cells prior to stem cell transplantation',
#  'mobilise progenitor cells prior to stem cell transplantation',
#  'moderate and severe closed traumatic brain injury',
#  'moderate and severe traumatic brain injury',
#  'molybdenum cofactor deficiency type a',
#  'mucopolysaccharidosis iiia (sanfilippo a syndrome)',
#  'mucopolysaccharidosis iiic (sanfilippo c syndrome)',
#  'mucopolysaccharidosis type ii (hunters syndrome)',
#  'mucopolysaccharidosis type iii (sanfilippo syndrome)',
#  'mucopolysaccharidosis type iiia (sanfilippo a syndrome)',
#  'mucopolysaccharidosis type iiib (sanfilippo b syndrome)',
#  'mucopolysaccharidosis type vi (maroteauxlamy syndrome)',
#  'mucopolysaccharidosis type vii (sly syndrome)',
#  'mucopolysaccharidosis, type iiia (sanfilippo a syndrome)',
#  'mucopolysaccharidosis, type iva (morquio a syndrome)',
#  'nacetylglutamate synthetase (nags) deficiency',
#  'nacetylglutamate synthetase deficiency',
#  'necrotising enterocolitis',
#  'necrotising soft tissue infections',
#  'neonatal diabetes',
#  'neonatal encephalopathy',
#  'neuronal ceroid lipofuscinosis type 2',
#  'non24hor sleepwake disorders in blind people with no light perception',
#  'nondystrophic myotonia',
#  'noninfectios uveitis',
#  'noninfectios uveitis affecting the posterior segment of the eye',
#  'noninsulinoma pancreatogenos hypoglycemia syndrome',
#  'nonpapillary transitional cell carcinoma of the urinary bladder',
#  'nontraumatic osteonecrosis',
#  'oesophageal cancer',
#  'oesophagus carcinoma',
#  'offperiods in parkinsons disease not responding to oral treatment',
#  'oral mucositis in head and neck cancer patients undergoing radiation therapy',
#  'ornithine translocase deficiency (hyperornithinemiahyperammonemia homocitrullinuria (hhh) syndrome)',
#  'ornithinetranscarbamylase deficiency',
#  'ornithinine transcarbamylase deficiency',
#  'orthostatic hypotension in patients with multiple system atrophy',
#  'orthostatic hypotension in patients with pure autonomic failure',
#  'pancreatic cancer in combination with ifosfamide',
#  'pantothenatekinaseassociated neurodegeneration',
#  'papillary thyroid cancer',
#  'partial deep dermal and full thickness burn wonds',
#  'partial deep dermal and full thickness burns',
#  'perinatal asphyxia',
#  'peripheral tcell lymphoma (nodal, other extranodal and leukemic/disseminated)',
#  'plasminogen deficiency',
#  'pneumonia caused by serotype o1 pseudomonas eruginosa',
#  'pneumonia caused by serotype o11 pseudomonas eruginosa',
#  'pneumonia caused by staphylococcus aureus',
#  'poliomyelitis in patients with immunodeficiencies deemed at risk',
#  'positive folate receptor status in ovarian cancer',
#  'post transplantation graft dysfunction',
#  'post transplantation lymphoproliferative disorders',
#  'postcardiotomy right ventricular failure',
#  'postessential thrombocythemia myelofibrosis',
#  'postpolycythemia vera myelofibrosis',
#  'posttransplant lymphoproliferative disorder',
#  'primary apnoea of premature newborns',
#  'primary coenzyme q10 deficiency syndrome',
#  'primary graft dysfunction following lung transplantation',
#  'primary growth hormone insensitivity syndrome',
#  'primary insulinlike growth factor1 deficiency due to molecular or genetic defects',
#  'progressive myoclonic epilepsy type 2 (lafora disease)',
#  'proopiomelanocortin deficiency',
#  'pseudohypoaldosteronism type 1b',
#  'pseudomonas eruginosa lung infection in cystic fibrosis',
#  'pulmonary arterial hypertension and chronic thromboembolic pulmonary hypertension',
#  'pulmonary arterial hypertension including treatment of chronic thromboembolic pulmonary hypertension',
#  'pulmonary fungal infection in patients deemed at risk',
#  'pyruvate kinase deficiency',
#  'recombinationactivating gene 1 deficient severe combined immunodeficiency',
#  'recurrent hepatitis c in liver transplant recipients',
#  'recurrent hepatitis c virus induced liver disease in liver transplant recipients',
#  'respiratory distress syndrome in premature neonates of less than 32 weeks of gestational age',
#  'respiratory distress syndrome in premature neonates of less than 37 weeks of gestational age',
#  'retinitis pigmentosa caused by mutations in the rpgr gene',
#  'retinitis pigmentosa in usher syndrome 1b',
#  'retinopathy of prematurity in neonates of less than 32 weeks of gestational age',
#  'rhodopsinlinked retinitis pigmentosa',
#  'scarring post glaucoma filtration surgery',
#  'sepsis in atrisk premature infants of less than or equal to 32 weeks of gestational age',
#  'severe closed traumatic brain injury',
#  'severe combined immunodeficiency (scid) due to adenosine deaminase (ada) deficiency',
#  'severe combined immunodeficiency (scid)xl disease',
#  'shigatoxin producing bacterial infection.',
#  'sickle cell syndrome',
#  'solitary bone cysts',
#  'sporadic lymphangioleiomyomatosis',
#  'squamos cell carcinoma of the head and neck in patients undergoing radiotherapy',
#  'staphylococcus aureus bacteremia',
#  'stargardts disease',
#  'stenosis in synthetic grafts used in hemodialysis',
#  'sudden sensorineural hearing loss',
#  'systemic amyloidosis caused by beta2 microglobulin',
#  'systemic light chain amyloidosis',
#  'systemic secondary amyloidosis',
#  'tenosynovial giant cell tumor, localised and diffuse type',
#  'tenosynovial giant cell tumor, localised and diffused type',
#  'tert positive nonsmall cell lung cancer in hlaa2 positive patients',
#  'the hepatocellular carcinoma',
#  'the ischemia/reperfusion injury associated with solid organ transplantation',
#  'the localised scleroderma',
#  'thromboangiitis obliterans (buergers disease)',
#  'transglutaminase1deficient autosomal recessive congenital ichthyosis',
#  'traumatic spinal cord injury',
#  'uremic pruritus',
#  'very longchain acylcoa dehydrogenase deficiency',
#  'wiskottaldrichsyndrome',
#  'xlinked hypohidrotic ectodermal dysplasia (christsiemenstoraine syndrome)',
#  'xlinked spinal and bulbar muscular atrophy (kennedys disease)',
#  'αmannosidosis'}

# %%
df['doid'] = df.indication.apply(doid_matches.get)
df['hpo'] = df.indication.apply(hpo_matches.get)
df['ordo'] = df.indication.apply(ordo_matches.get)
df['mesh'] = df.indication.apply(mesh_matches.get)

# %%
df.head()
# Out:
#                                              Product EU Designation  \
# 0  11-(2-pyrrolidin-1-yl-ethoxy)-14,19-dioxa-5,7,...    EU/3/10/767
# 1  11-(2-pyrrolidin-1-yl-ethoxy)-14,19-dioxa-5,7,...    EU/3/10/768
# 2  11-(2-pyrrolidin-1-yl-ethoxy)-14,19-dioxa-5,7,...    EU/3/10/769
# 3  11-(4-Dimethylamino-3-hydroxy-6-methyl-tetrahy...   EU/3/14/1239
# 4  1-(2,2-difluoro-1,3-benzodioxol-5-yl)-N-{1-[(2...   EU/3/14/1281
#
#                         Designated Orphan Indication  \
# 0  Treatment of post-essential thrombocythaemia m...
# 1                 Treatment of primary myelofibrosis
# 2  Treatment of post-polycythaemia vera myelofibr...
# 3                       Treatment of cystic fibrosis
# 4                       Treatment of cystic fibrosis
#
#                                    Sponsor Designation date  \
# 0                    CTI Life Sciences Ltd       25/08/2010
# 1                    CTI Life Sciences Ltd       25/08/2010
# 2                    CTI Life Sciences Ltd       25/08/2010
# 3                              Synovo GmbH       19/02/2014
# 4  Vertex Pharmaceuticals (Europe) Limited       04/07/2014
#
#   TradenameEU Centralised NrImplemented on drug_qid  \
# 0                                      NaN      NaN
# 1                                      NaN      NaN
# 2                                      NaN      NaN
# 3                                      NaN      NaN
# 4                                      NaN      NaN
#
#                                     indication  \
# 0  postessential thrombocythemia myelofibrosis
# 1                        primary myelofibrosis
# 2          postpolycythemia vera myelofibrosis
# 3                              cystic fibrosis
# 4                              cystic fibrosis
#
#                                        doid   hpo  \
# 0                                      None  None
# 1  http://purl.obolibrary.org/obo/DOID_4971  None
# 2                                      None  None
# 3  http://purl.obolibrary.org/obo/DOID_1485  None
# 4  http://purl.obolibrary.org/obo/DOID_1485  None
#
#                                      ordo     mesh
# 0                                    None     None
# 1  http://www.orpha.net/ORDO/Orphanet_824  D055728
# 2                                    None     None
# 3  http://www.orpha.net/ORDO/Orphanet_586  D003550
# 4  http://www.orpha.net/ORDO/Orphanet_586  D003550

# %%
doid_wd = wdi_helpers.id_mapper("P699")
ordo_wd = wdi_helpers.id_mapper("P1550")
mesh_wd = wdi_helpers.id_mapper("P486")

# %%
df.loc[:,'indication_qid_doid'] = df.doid.dropna().apply(lambda x:doid_wd.get(x.split("/")[-1].replace("_",":")))
df.loc[:,'indication_qid_ordo'] = df.ordo.dropna().apply(lambda x:ordo_wd.get(x.split("_")[-1]))
df.loc[:,'indication_qid_mesh'] = df.mesh.dropna().apply(mesh_wd.get)

# %%
df.head()
# Out:
#                                              Product EU Designation  \
# 0  11-(2-pyrrolidin-1-yl-ethoxy)-14,19-dioxa-5,7,...    EU/3/10/767
# 1  11-(2-pyrrolidin-1-yl-ethoxy)-14,19-dioxa-5,7,...    EU/3/10/768
# 2  11-(2-pyrrolidin-1-yl-ethoxy)-14,19-dioxa-5,7,...    EU/3/10/769
# 3  11-(4-Dimethylamino-3-hydroxy-6-methyl-tetrahy...   EU/3/14/1239
# 4  1-(2,2-difluoro-1,3-benzodioxol-5-yl)-N-{1-[(2...   EU/3/14/1281
#
#                         Designated Orphan Indication  \
# 0  Treatment of post-essential thrombocythaemia m...
# 1                 Treatment of primary myelofibrosis
# 2  Treatment of post-polycythaemia vera myelofibr...
# 3                       Treatment of cystic fibrosis
# 4                       Treatment of cystic fibrosis
#
#                                    Sponsor Designation date  \
# 0                    CTI Life Sciences Ltd       25/08/2010
# 1                    CTI Life Sciences Ltd       25/08/2010
# 2                    CTI Life Sciences Ltd       25/08/2010
# 3                              Synovo GmbH       19/02/2014
# 4  Vertex Pharmaceuticals (Europe) Limited       04/07/2014
#
#   TradenameEU Centralised NrImplemented on drug_qid  \
# 0                                      NaN      NaN
# 1                                      NaN      NaN
# 2                                      NaN      NaN
# 3                                      NaN      NaN
# 4                                      NaN      NaN
#
#                                     indication  \
# 0  postessential thrombocythemia myelofibrosis
# 1                        primary myelofibrosis
# 2          postpolycythemia vera myelofibrosis
# 3                              cystic fibrosis
# 4                              cystic fibrosis
#
#                                        doid   hpo  \
# 0                                      None  None
# 1  http://purl.obolibrary.org/obo/DOID_4971  None
# 2                                      None  None
# 3  http://purl.obolibrary.org/obo/DOID_1485  None
# 4  http://purl.obolibrary.org/obo/DOID_1485  None
#
#                                      ordo     mesh indication_qid_doid  \
# 0                                    None     None                 NaN
# 1  http://www.orpha.net/ORDO/Orphanet_824  D055728            Q1752571
# 2                                    None     None                 NaN
# 3  http://www.orpha.net/ORDO/Orphanet_586  D003550             Q178194
# 4  http://www.orpha.net/ORDO/Orphanet_586  D003550             Q178194
#
#   indication_qid_ordo indication_qid_mesh
# 0                 NaN                 NaN
# 1                None            Q1752571
# 2                 NaN                 NaN
# 3                None             Q178194
# 4                None             Q178194

# %%
df.to_csv("eu_orphan_match.csv")

# %%
good_df=df[df.indication_qid_doid.notnull() & df.drug_qid.notnull()]
good_df
# Out:
#                                                 Product EU Designation  \
# 23    17a,21-dihydroxy-16a-methyl-pregna-1,4,9(11)-t...   EU/3/14/1309
# 25              1-deoxygalactonojirimycin hydrochloride    EU/3/06/368
# 42    2-((2-ethyl-6-(4-(2-(3-hydroxyazetidin-1-yl)-2...   EU/3/16/1712
# 86                        3,5-diiodothyropropionic acid   EU/3/13/1193
# 93    (3S)-1-azabicyclo[2.2.2]oct-3-yl{2-[2-(4-fluor...   EU/3/14/1310
# 94    (3S)-1-azabicyclo[2.2.2]oct-3-yl{2-[2-(4-fluor...   EU/3/14/1374
# 102   4’-[(2-butyl-4-oxo-1,3-diazaspiro[4.4]non-1-en...   EU/3/15/1574
# 166                                           Acadesine    EU/3/11/881
# 168                                       Acalabrutinib   EU/3/16/1625
# 169                                       Acalabrutinib   EU/3/16/1626
# 170                                 Acamprosate calcium   EU/3/14/1337
# 171                            Acebutolol hydrochloride   EU/3/16/1742
# 172                                Acetylsalicylic acid    EU/3/04/208
# 201   Adeno-associated viral vector serotype 8 encod...   EU/3/16/1623
# 218   Adenovirus associated viral vector serotype 5 ...   EU/3/13/1142
# 232                                           Aganirsen   EU/3/14/1275
# 235                                           Allantoin   EU/3/13/1232
# 270                                    Alpha-tocopherol   EU/3/16/1775
# 272                                           Alvocidib    EU/3/07/485
# 273                                           Alvocidib   EU/3/15/1437
# 274                                          Amatuximab   EU/3/13/1222
# 293                                       Antroquinonol   EU/3/16/1812
# 294                                            Aplidine    EU/3/04/245
# 298                                         Arimoclomol    EU/3/06/406
# 300                                 Arimoclomol citrate   EU/3/16/1659
# 301                                    Arsenic trioxide   EU/3/16/1610
# 303                                          artesunate    EU/3/07/430
# 304                                          artesunate    EU/3/07/510
# 305                                          Artesunate   EU/3/12/1079
# 306                                          Artesunate   EU/3/15/1521
# ...                                                 ...            ...
# 1355                                        Thymalfasin    EU/3/02/110
# 1356                                         Tideglusib   EU/3/15/1452
# 1357                                         Tipifarnib    EU/3/05/269
# 1358                                         Tivantinib   EU/3/13/1202
# 1360                                    Tolfenamic acid   EU/3/16/1613
# 1363                                         Tosedostat    EU/3/09/659
# 1364                                        Trabectedin    EU/3/03/171
# 1370                                         Trebananib   EU/3/13/1207
# 1371                                          Trehalose   EU/3/15/1496
# 1378                                         Tretazicar    EU/3/08/529
# 1381                       Trientine tetrahydrochloride   EU/3/15/1471
# 1386                                       Triheptanoin   EU/3/15/1526
# 1387                                       Triheptanoin   EU/3/16/1710
# 1388  Two allogenic irradiated pancreatic tumour cel...   EU/3/15/1604
# 1397                                        Ulocuplumab   EU/3/15/1445
# 1400                                      Valproic Acid   EU/3/16/1734
# 1401                                      Valproic acid   EU/3/16/1792
# 1407                                 Velaglucerase alfa    EU/3/10/752
# 1408                                          Veliparib    EU/3/10/830
# 1409                                         Veltuzumab    EU/3/09/713
# 1411                                         Venetoclax   EU/3/16/1617
# 1412                                         Venetoclax   EU/3/16/1766
# 1413                                         Venetoclax   EU/3/16/1767
# 1417                                Volanesorsen sodium   EU/3/16/1711
# 1418                                         Volasertib   EU/3/14/1255
# 1419                                          Vosaroxin    EU/3/12/990
# 1429                                     Zinc gluconate   EU/3/16/1793
# 1430                                    Zoledronic acid   EU/3/13/1192
# 1431                                    Zoledronic acid   EU/3/16/1735
# 1432                        Zosuquidar trihydrochloride    EU/3/06/355
#
#                            Designated Orphan Indication  \
# 23             Treatment of Duchenne muscular dystrophy
# 25                           Treatment of Fabry disease
# 42           Treatment of idiopathic pulmonary fibrosis
# 86           Treatment of Allan-Herndon-Dudley syndrome
# 93                           Treatment of Fabry disease
# 94                         Treatment of Gaucher disease
# 102     Treatment of focal segmental glomerulosclerosis
# 166                       Treatment of multiple myeloma
# 168                   Treatment of mantle cell lymphoma
# 169             Treatment of lymphoplasmacytic lymphoma
# 170                     Treatment of fragile X syndrome
# 171                 Treatment of Smith-Magenis syndrome
# 172                      Treatment of polycythemia vera
# 201   Treatment of ornithine transcarbamylase defici...
# 218                   Treatment of retinitis pigmentosa
# 232         Treatment of central retinal vein occlusion
# 235                  Treatment of epidermolysis bullosa
# 270   Treatment of facioscapulohumeral muscular dyst...
# 272          Treatment of chronic lymphocytic leukaemia
# 273                Treatment of acute myeloid leukaemia
# 274                 Treatment of malignant mesothelioma
# 293                      Treatment of pancreatic cancer
# 294                       Treatment of multiple myeloma
# 298          Treatment of amyotrophic lateral sclerosis
# 300                Treatment of inclusion body myositis
# 301                Treatment of acute myeloid leukaemia
# 303                                Treatment of malaria
# 304                                Treatment of malaria
# 305                                Treatment of malaria
# 306                                Treatment of malaria
# ...                                                 ...
# 1355              Treatment of hepatocellular carcinoma
# 1356                    Treatment of fragile X syndrome
# 1357               Treatment of acute myeloid leukaemia
# 1358              Treatment of hepatocellular carcinoma
# 1360        Treatment of progressive supranuclear palsy
# 1363               Treatment of acute myeloid leukaemia
# 1364                        Treatment of ovarian cancer
# 1370                        Treatment of ovarian cancer
# 1371    Treatment of oculopharyngeal muscular dystrophy
# 1378                Treatment of visceral leishmaniasis
# 1381                Treatment of Wilson&#8217;s disease
# 1386  Treatment of carnitine palmitoyltransferase II...
# 1387               Treatment of McArdle&#8217;s disease
# 1388                     Treatment of pancreatic cancer
# 1397               Treatment of acute myeloid leukaemia
# 1400               Treatment of McArdle&#8217;s disease
# 1401         Treatment of diffuse large B-cell lymphoma
# 1407                       Treatment of Gaucher disease
# 1408                        Treatment of ovarian cancer
# 1409         Treatment of chronic lymphocytic leukaemia
# 1411               Treatment of acute myeloid leukaemia
# 1412         Treatment of diffuse large B-cell lymphoma
# 1413                      Treatment of multiple myeloma
# 1417        Treatment of familial partial lipodystrophy
# 1418               Treatment of acute myeloid leukaemia
# 1419               Treatment of acute myeloid leukaemia
# 1429  Treatment of facioscapulohumeral muscular dyst...
# 1430        Treatment of complex regional pain syndrome
# 1431                                Treatment of glioma
# 1432               Treatment of acute myeloid leukaemia
#
#                                                 Sponsor Designation date  \
# 23                          ReveraGen BioPharma Limited       22/08/2014
# 25                           Amicus Therapeutics UK Ltd       22/05/2006
# 42                                         Galapagos NV       29/08/2016
# 86                                CATS Consultants GmbH       07/10/2013
# 93                                  Genzyme Europe B.V.       22/08/2014
# 94                                  Genzyme Europe B.V.       19/11/2014
# 102                            Retrophin Europe Limited       11/11/2015
# 166   Advancell - Advanced In Vitro Cell Technologie...       05/08/2011
# 168                                   Acerta Pharma, BV       21/03/2016
# 169                                   Acerta Pharma, BV       21/03/2016
# 170                             Real Regulatory Limited       15/10/2014
# 171                                      Therapicon Srl       14/10/2016
# 172                                 Bayer HealthCare AG       29/07/2004
# 201                                   Pharma Gateway AB       21/03/2016
# 218                                           HORAMA SA       19/06/2013
# 232                                     Gene Signal SAS       10/06/2014
# 235                          Amicus Therapeutics UK Ltd       16/01/2014
# 270                           Université de Montpellier       18/11/2016
# 272                      Theorem Clinical Research GmbH       23/10/2007
# 273                      Theorem Clinical Research GmbH       12/02/2015
# 274                                Eisai Europe Limited       16/01/2014
# 293                    Biological Consulting Europe Ltd       12/01/2017
# 294                                     Pharma Mar S.A.       16/11/2004
# 298                                       Orphazyme ApS       26/10/2006
# 300                                       Orphazyme ApS       30/05/2016
# 301                                 Orsenix Holdings BV       17/02/2016
# 303                              ACE Pharmaceuticals BV       20/02/2007
# 304     Sigma-Tau Industrie Farmaceutiche Riunite S.p.A       06/12/2007
# 305                       Dafra Pharma International NV       06/12/2012
# 306                                   Dr Ulrich Granzer       28/07/2015
# ...                                                 ...              ...
# 1355               SciClone Pharmaceuticals Italy S.r.l       30/07/2002
# 1356                                     AMO Pharma Ltd       19/03/2015
# 1357                            TMC Pharma Services Ltd       10/03/2005
# 1358                         Daiichi Sankyo Europe GmbH       13/11/2013
# 1360                                   RV Developpement       17/02/2016
# 1363                         Voisin Consulting S.A.R.L.       24/07/2009
# 1364                                    Pharma Mar S.A.       17/10/2003
# 1370                                  Amgen Europe B.V.       13/11/2013
# 1371                                  Dr Ulrich Granzer       21/05/2015
# 1378                          Morvus Technology Limited       04/02/2008
# 1381                                      GMP-Orphan SA       19/03/2015
# 1386                              Ultragenyx UK Limited       28/07/2015
# 1387                Vall d'Hebron Institute of Research       14/07/2016
# 1388                Aduro Biotech Holdings, Europe B.V.       11/01/2016
# 1397                   Bristol-Myers Squibb Pharma EEIG       12/02/2015
# 1400                Vall d'Hebron Institute of Research       29/08/2016
# 1401                                        Valcuria AB       18/11/2016
# 1407              Shire Pharmaceuticals Ireland Limited       09/06/2010
# 1408                                         AbbVie Ltd       17/12/2010
# 1409                                  Immunomedics GmbH       29/01/2010
# 1411                                         AbbVie Ltd       17/02/2016
# 1412                                         AbbVie Ltd       14/10/2016
# 1413                                         AbbVie Ltd       14/10/2016
# 1417                                  Ionis USA Limited       14/07/2016
# 1418            Boehringer Ingelheim International GmbH       26/03/2014
# 1419                                 Sunesis Europe Ltd       26/04/2012
# 1429                          Université de Montpellier       18/11/2016
# 1430                        Axsome Therapeutics Limited       07/10/2013
# 1431  Laboratorio Italiano Biochimico Farmaceutico L...       29/08/2016
# 1432  Kanisa Europe Limited, Mofo Notices Limited, C...       17/02/2006
#
#      TradenameEU Centralised NrImplemented on   drug_qid  \
# 23                                        NaN  Q27270940
# 25             GalafoldEU/1/15/108231/05/2016  Q27291314
# 42                                        NaN    Q407204
# 86                                        NaN  Q27252433
# 93                                        NaN  Q27077129
# 94                                        NaN  Q27077129
# 102                                       NaN  Q27896056
# 166                                       NaN   Q4671562
# 168                                       NaN  Q27074143
# 169                                       NaN  Q27074143
# 170                                       NaN  Q27122289
# 171                                       NaN  Q27105651
# 172                                       NaN     Q18216
# 201                                       NaN  Q27896091
# 218                                       NaN  Q27270104
# 232                                       NaN  Q15633943
# 235                                       NaN    Q409804
# 270                                       NaN    Q158348
# 272                                       NaN   Q4063441
# 273                                       NaN   Q4063441
# 274                                       NaN   Q4740637
# 293                                       NaN  Q27133859
# 294                                       NaN   Q4779975
# 298                                       NaN   Q4790694
# 300                                       NaN  Q27287107
# 301                                       NaN  Q26841209
# 303                                       NaN    Q707939
# 304                                       NaN    Q707939
# 305                                       NaN    Q707939
# 306                                       NaN    Q707939
# ...                                       ...        ...
# 1355                                      NaN  Q20817234
# 1356                                      NaN  Q10382411
# 1357                                      NaN   Q7808830
# 1358                                      NaN  Q17123902
# 1360                                      NaN     Q59412
# 1363                                      NaN  Q27166812
# 1364            YondelisEU/1/07/41730/10/2009   Q2637746
# 1370                                      NaN  Q27272385
# 1371                                      NaN  Q27109935
# 1378                                      NaN  Q27095075
# 1381                                      NaN  Q27266138
# 1386                                      NaN    Q414576
# 1387                                      NaN    Q414576
# 1388                                      NaN  Q27253946
# 1397                                      NaN  Q21098907
# 1400                                      NaN    Q240642
# 1401                                      NaN    Q240642
# 1407               VPRIVEU/1/10/64630/08/2010   Q3492447
# 1408                                      NaN   Q7919041
# 1409                                      NaN   Q4009438
# 1411                                      NaN  Q23671272
# 1412                                      NaN  Q23671272
# 1413                                      NaN  Q23671272
# 1417                                      NaN  Q27265010
# 1418                                      NaN   Q7939986
# 1419                                      NaN  Q18395775
# 1429                                      NaN   Q3822815
# 1430                                      NaN    Q218507
# 1431                                      NaN    Q218507
# 1432                                      NaN  Q27269191
#
#                                         indication  \
# 23                     duchenne muscular dystrophy
# 25                                   fabry disease
# 42                   idiopathic pulmonary fibrosis
# 86                     allanherndondudley syndrome
# 93                                   fabry disease
# 94                                 gaucher disease
# 102             focal segmental glomerulosclerosis
# 166                               multiple myeloma
# 168                           mantle cell lymphoma
# 169                     lymphoplasmacytic lymphoma
# 170                             fragile x syndrome
# 171                          smithmagenis syndrome
# 172                              polycythemia vera
# 201          ornithine transcarbamylase deficiency
# 218                           retinitis pigmentosa
# 232                 central retinal vein occlusion
# 235                          epidermolysis bullosa
# 270         facioscapulohumeral muscular dystrophy
# 272                   chronic lymphocytic leukemia
# 273                         acute myeloid leukemia
# 274                         malignant mesothelioma
# 293                              pancreatic cancer
# 294                               multiple myeloma
# 298                  amyotrophic lateral sclerosis
# 300                        inclusion body myositis
# 301                         acute myeloid leukemia
# 303                                        malaria
# 304                                        malaria
# 305                                        malaria
# 306                                        malaria
# ...                                            ...
# 1355                      hepatocellular carcinoma
# 1356                            fragile x syndrome
# 1357                        acute myeloid leukemia
# 1358                      hepatocellular carcinoma
# 1360                progressive supranuclear palsy
# 1363                        acute myeloid leukemia
# 1364                                ovarian cancer
# 1370                                ovarian cancer
# 1371            oculopharyngeal muscular dystrophy
# 1378                        visceral leishmaniasis
# 1381                               wilsons disease
# 1386  carnitine palmitoyltransferase ii deficiency
# 1387                              mcardles disease
# 1388                             pancreatic cancer
# 1397                        acute myeloid leukemia
# 1400                              mcardles disease
# 1401                  diffuse large bcell lymphoma
# 1407                               gaucher disease
# 1408                                ovarian cancer
# 1409                  chronic lymphocytic leukemia
# 1411                        acute myeloid leukemia
# 1412                  diffuse large bcell lymphoma
# 1413                              multiple myeloma
# 1417                familial partial lipodystrophy
# 1418                        acute myeloid leukemia
# 1419                        acute myeloid leukemia
# 1429        facioscapulohumeral muscular dystrophy
# 1430                complex regional pain syndrome
# 1431                                        glioma
# 1432                        acute myeloid leukemia
#
#                                              doid  \
# 23      http://purl.obolibrary.org/obo/DOID_11723
# 25      http://purl.obolibrary.org/obo/DOID_14499
# 42    http://purl.obolibrary.org/obo/DOID_0050156
# 86    http://purl.obolibrary.org/obo/DOID_0050631
# 93      http://purl.obolibrary.org/obo/DOID_14499
# 94       http://purl.obolibrary.org/obo/DOID_1926
# 102      http://purl.obolibrary.org/obo/DOID_1312
# 166      http://purl.obolibrary.org/obo/DOID_9538
# 168   http://purl.obolibrary.org/obo/DOID_0050746
# 169   http://purl.obolibrary.org/obo/DOID_0050747
# 170     http://purl.obolibrary.org/obo/DOID_14261
# 171   http://purl.obolibrary.org/obo/DOID_0060768
# 172      http://purl.obolibrary.org/obo/DOID_8997
# 201      http://purl.obolibrary.org/obo/DOID_9271
# 218     http://purl.obolibrary.org/obo/DOID_10584
# 232      http://purl.obolibrary.org/obo/DOID_2450
# 235      http://purl.obolibrary.org/obo/DOID_2730
# 270     http://purl.obolibrary.org/obo/DOID_11727
# 272      http://purl.obolibrary.org/obo/DOID_1040
# 273      http://purl.obolibrary.org/obo/DOID_9119
# 274      http://purl.obolibrary.org/obo/DOID_1790
# 293      http://purl.obolibrary.org/obo/DOID_1793
# 294      http://purl.obolibrary.org/obo/DOID_9538
# 298       http://purl.obolibrary.org/obo/DOID_332
# 300      http://purl.obolibrary.org/obo/DOID_3429
# 301      http://purl.obolibrary.org/obo/DOID_9119
# 303     http://purl.obolibrary.org/obo/DOID_12365
# 304     http://purl.obolibrary.org/obo/DOID_12365
# 305     http://purl.obolibrary.org/obo/DOID_12365
# 306     http://purl.obolibrary.org/obo/DOID_12365
# ...                                           ...
# 1355      http://purl.obolibrary.org/obo/DOID_684
# 1356    http://purl.obolibrary.org/obo/DOID_14261
# 1357     http://purl.obolibrary.org/obo/DOID_9119
# 1358      http://purl.obolibrary.org/obo/DOID_684
# 1360      http://purl.obolibrary.org/obo/DOID_678
# 1363     http://purl.obolibrary.org/obo/DOID_9119
# 1364     http://purl.obolibrary.org/obo/DOID_2394
# 1370     http://purl.obolibrary.org/obo/DOID_2394
# 1371    http://purl.obolibrary.org/obo/DOID_11719
# 1378     http://purl.obolibrary.org/obo/DOID_9146
# 1381      http://purl.obolibrary.org/obo/DOID_893
# 1386  http://purl.obolibrary.org/obo/DOID_0060235
# 1387     http://purl.obolibrary.org/obo/DOID_2746
# 1388     http://purl.obolibrary.org/obo/DOID_1793
# 1397     http://purl.obolibrary.org/obo/DOID_9119
# 1400     http://purl.obolibrary.org/obo/DOID_2746
# 1401  http://purl.obolibrary.org/obo/DOID_0050745
# 1407     http://purl.obolibrary.org/obo/DOID_1926
# 1408     http://purl.obolibrary.org/obo/DOID_2394
# 1409     http://purl.obolibrary.org/obo/DOID_1040
# 1411     http://purl.obolibrary.org/obo/DOID_9119
# 1412  http://purl.obolibrary.org/obo/DOID_0050745
# 1413     http://purl.obolibrary.org/obo/DOID_9538
# 1417  http://purl.obolibrary.org/obo/DOID_0050440
# 1418     http://purl.obolibrary.org/obo/DOID_9119
# 1419     http://purl.obolibrary.org/obo/DOID_9119
# 1429    http://purl.obolibrary.org/obo/DOID_11727
# 1430     http://purl.obolibrary.org/obo/DOID_3223
# 1431     http://purl.obolibrary.org/obo/DOID_3070
# 1432     http://purl.obolibrary.org/obo/DOID_9119
#
#                                             hpo  \
# 23                                         None
# 25                                         None
# 42                                         None
# 86                                         None
# 93                                         None
# 94                                         None
# 102   http://purl.obolibrary.org/obo/HP_0000097
# 166   http://purl.obolibrary.org/obo/HP_0006775
# 168                                        None
# 169                                        None
# 170                                        None
# 171                                        None
# 172                                        None
# 201                                        None
# 218   http://purl.obolibrary.org/obo/HP_0000510
# 232                                        None
# 235                                        None
# 270                                        None
# 272   http://purl.obolibrary.org/obo/HP_0005550
# 273   http://purl.obolibrary.org/obo/HP_0004808
# 274   http://purl.obolibrary.org/obo/HP_0100001
# 293   http://purl.obolibrary.org/obo/HP_0002894
# 294   http://purl.obolibrary.org/obo/HP_0006775
# 298   http://purl.obolibrary.org/obo/HP_0007354
# 300                                        None
# 301   http://purl.obolibrary.org/obo/HP_0004808
# 303                                        None
# 304                                        None
# 305                                        None
# 306                                        None
# ...                                         ...
# 1355  http://purl.obolibrary.org/obo/HP_0001402
# 1356                                       None
# 1357  http://purl.obolibrary.org/obo/HP_0004808
# 1358  http://purl.obolibrary.org/obo/HP_0001402
# 1360                                       None
# 1363  http://purl.obolibrary.org/obo/HP_0004808
# 1364                                       None
# 1370                                       None
# 1371                                       None
# 1378                                       None
# 1381                                       None
# 1386                                       None
# 1387                                       None
# 1388  http://purl.obolibrary.org/obo/HP_0002894
# 1397  http://purl.obolibrary.org/obo/HP_0004808
# 1400                                       None
# 1401                                       None
# 1407                                       None
# 1408                                       None
# 1409  http://purl.obolibrary.org/obo/HP_0005550
# 1411  http://purl.obolibrary.org/obo/HP_0004808
# 1412                                       None
# 1413  http://purl.obolibrary.org/obo/HP_0006775
# 1417                                       None
# 1418  http://purl.obolibrary.org/obo/HP_0004808
# 1419  http://purl.obolibrary.org/obo/HP_0004808
# 1429                                       None
# 1430                                       None
# 1431  http://purl.obolibrary.org/obo/HP_0009733
# 1432  http://purl.obolibrary.org/obo/HP_0004808
#
#                                            ordo     mesh indication_qid_doid  \
# 23     http://www.orpha.net/ORDO/Orphanet_98896  D020388            Q1648484
# 25       http://www.orpha.net/ORDO/Orphanet_324  D000795             Q615645
# 42      http://www.orpha.net/ORDO/Orphanet_2032  D054990            Q2290446
# 86        http://www.orpha.net/ORDO/Orphanet_59     None            Q4731121
# 93       http://www.orpha.net/ORDO/Orphanet_324  D000795             Q615645
# 94       http://www.orpha.net/ORDO/Orphanet_355  D005776             Q861645
# 102                                        None  D005923            Q1435223
# 166    http://www.orpha.net/ORDO/Orphanet_29073  D009101             Q467635
# 168    http://www.orpha.net/ORDO/Orphanet_52416  D020522             Q268713
# 169                                        None     None            Q1778287
# 170      http://www.orpha.net/ORDO/Orphanet_908  D005600             Q221472
# 171      http://www.orpha.net/ORDO/Orphanet_819  D058496            Q2295338
# 172      http://www.orpha.net/ORDO/Orphanet_729  D011087             Q948318
# 201      http://www.orpha.net/ORDO/Orphanet_664  D020163            Q3043161
# 218      http://www.orpha.net/ORDO/Orphanet_791  D012174             Q847057
# 232                                        None     None             Q190831
# 235                                        None  D004820             Q923020
# 270      http://www.orpha.net/ORDO/Orphanet_269  D020391            Q1399182
# 272                                        None  D015451            Q1088156
# 273      http://www.orpha.net/ORDO/Orphanet_519  D015470             Q264118
# 274                                        None     None            Q1077603
# 293                                        None  D010190             Q212961
# 294    http://www.orpha.net/ORDO/Orphanet_29073  D009101             Q467635
# 298      http://www.orpha.net/ORDO/Orphanet_803  D000690             Q206901
# 300      http://www.orpha.net/ORDO/Orphanet_611  D018979            Q1848471
# 301      http://www.orpha.net/ORDO/Orphanet_519  D015470             Q264118
# 303      http://www.orpha.net/ORDO/Orphanet_673  D008288              Q12156
# 304      http://www.orpha.net/ORDO/Orphanet_673  D008288              Q12156
# 305      http://www.orpha.net/ORDO/Orphanet_673  D008288              Q12156
# 306      http://www.orpha.net/ORDO/Orphanet_673  D008288              Q12156
# ...                                         ...      ...                 ...
# 1355   http://www.orpha.net/ORDO/Orphanet_88673  D006528            Q1148337
# 1356     http://www.orpha.net/ORDO/Orphanet_908  D005600             Q221472
# 1357     http://www.orpha.net/ORDO/Orphanet_519  D015470             Q264118
# 1358   http://www.orpha.net/ORDO/Orphanet_88673  D006528            Q1148337
# 1360     http://www.orpha.net/ORDO/Orphanet_683  D013494             Q945930
# 1363     http://www.orpha.net/ORDO/Orphanet_519  D015470             Q264118
# 1364  http://www.orpha.net/ORDO/Orphanet_213500  D010051             Q172341
# 1370  http://www.orpha.net/ORDO/Orphanet_213500  D010051             Q172341
# 1371     http://www.orpha.net/ORDO/Orphanet_270  D039141            Q3042171
# 1378                                       None  D007898            Q2046113
# 1381                                       None  D006527             Q117121
# 1386     http://www.orpha.net/ORDO/Orphanet_157     None            Q2033861
# 1387                                       None  D006012             Q787751
# 1388                                       None  D010190             Q212961
# 1397     http://www.orpha.net/ORDO/Orphanet_519  D015470             Q264118
# 1400                                       None  D006012             Q787751
# 1401     http://www.orpha.net/ORDO/Orphanet_544     None            Q2626074
# 1407     http://www.orpha.net/ORDO/Orphanet_355  D005776             Q861645
# 1408  http://www.orpha.net/ORDO/Orphanet_213500  D010051             Q172341
# 1409                                       None  D015451            Q1088156
# 1411     http://www.orpha.net/ORDO/Orphanet_519  D015470             Q264118
# 1412     http://www.orpha.net/ORDO/Orphanet_544     None            Q2626074
# 1413   http://www.orpha.net/ORDO/Orphanet_29073  D009101             Q467635
# 1417   http://www.orpha.net/ORDO/Orphanet_98306  D052496            Q5432945
# 1418     http://www.orpha.net/ORDO/Orphanet_519  D015470             Q264118
# 1419     http://www.orpha.net/ORDO/Orphanet_519  D015470             Q264118
# 1429     http://www.orpha.net/ORDO/Orphanet_269  D020391            Q1399182
# 1430   http://www.orpha.net/ORDO/Orphanet_83452     None            Q1066311
# 1431  http://www.orpha.net/ORDO/Orphanet_182067  D005910            Q1365309
# 1432     http://www.orpha.net/ORDO/Orphanet_519  D015470             Q264118
#
#      indication_qid_ordo indication_qid_mesh
# 23                  None            Q1648484
# 25                  None             Q615645
# 42                  None            Q2290446
# 86              Q4731121                 NaN
# 93                  None             Q615645
# 94               Q861645             Q861645
# 102                  NaN            Q1435223
# 166                 None             Q467635
# 168                 None                None
# 169                  NaN                 NaN
# 170              Q221472             Q221472
# 171                 None                None
# 172                 None             Q948318
# 201                 None            Q3043161
# 218              Q847057             Q847057
# 232                  NaN                 NaN
# 235                  NaN             Q923020
# 270                 None            Q1399182
# 272                  NaN            Q1088156
# 273                 None             Q264118
# 274                  NaN                 NaN
# 293                  NaN             Q212961
# 294                 None             Q467635
# 298            Q21124521             Q206901
# 300                 None            Q1848471
# 301                 None             Q264118
# 303                 None              Q12156
# 304                 None              Q12156
# 305                 None              Q12156
# 306                 None              Q12156
# ...                  ...                 ...
# 1355                None            Q1148337
# 1356             Q221472             Q221472
# 1357                None             Q264118
# 1358                None            Q1148337
# 1360             Q945930             Q945930
# 1363                None             Q264118
# 1364                None             Q172341
# 1370                None             Q172341
# 1371                None            Q3042171
# 1378                 NaN            Q2046113
# 1381                 NaN             Q117121
# 1386            Q2033861                 NaN
# 1387                 NaN             Q787751
# 1388                 NaN             Q212961
# 1397                None             Q264118
# 1400                 NaN             Q787751
# 1401                None                 NaN
# 1407             Q861645             Q861645
# 1408                None             Q172341
# 1409                 NaN            Q1088156
# 1411                None             Q264118
# 1412                None                 NaN
# 1413                None             Q467635
# 1417            Q5432945            Q5432945
# 1418                None             Q264118
# 1419                None             Q264118
# 1429                None            Q1399182
# 1430                None                 NaN
# 1431            Q1365309           Q18556612
# 1432                None             Q264118
#
# [300 rows x 15 columns]

# %%
len(good_df)
# Out:
# 300
